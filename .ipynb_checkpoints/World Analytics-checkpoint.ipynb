# %% [markdown]
# # Analytics for the usefulness for different government measures

# %% [markdown]
# This notebook analyzes the impact of different government measures on the number of people infected cases by the  covid-19 virus. Many countries have taken measures in varying degrees and combinations such as closed schools and workplaces, canceled public events and/or closed off public transportation. However, not every country can expect the same successful outcome due to complex political, economic, social and cultural differences.
# We conduct the following data analysis on various datasets publicly available.
#
# 1. <b>Analyze the before/after impact of various government measures: </b>
# a comparison between the trajectory of confirmed cases before the implementation and the observed number of cases after the measure is implemented
#
# 1. <b>Analysis on the reasoning behind varying successes/failures of each measure: </b>
# analyze the economic/political characteristics of countries with success/failure in each measure
#
# 1. (Nice to Have) a predictive model for fitting the logistic curve on to the observed number of cases, incorporating various features.

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np 
import pandas as pd 
from IPython.display import Image
from datetime import datetime, timedelta

# %%
sns.set(rc={'figure.figsize':(40, 30)})
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
#  # 1. Data Exploration

# %% [markdown]
# ## Oxford COVID-19 Government Response Tracker
# https://www.bsg.ox.ac.uk/research/research-projects/oxford-covid-19-government-response-tracker

# %%
data_dirname = "world_dataset"
oxford_fname = os.path.join(data_dirname, "OxCGRT_Download_latest_data-1.csv")
oxford_data = pd.read_csv(oxford_fname)
oxford_data
# Out:
#                 CountryName CountryCode      Date  S1_School closing  \
# 0               Afghanistan         AFG  20200101                0.0
# 1                    Angola         AGO  20200101                0.0
# 2      United Arab Emirates         ARE  20200101                NaN
# 3                 Argentina         ARG  20200101                0.0
# 4                   Armenia         ARM  20200101                NaN
# ...                     ...         ...       ...                ...
# 10556                Russia         RUS  20200331                NaN
# 10557                Rwanda         RWA  20200331                2.0
# 10558                Serbia         SRB  20200331                2.0
# 10559               Ukraine         UKR  20200331                2.0
# 10560             Venezuela         VEN  20200331                2.0
#
#        S1_IsGeneral                                           S1_Notes  \
# 0               1.0  https://en.unesco.org/themes/education-emergen...
# 1               NaN                                                NaN
# 2               NaN                                                NaN
# 3               NaN                                                NaN
# 4               NaN                                                NaN
# ...             ...                                                ...
# 10556           NaN                                                NaN
# 10557           1.0  Link: https://www.newvision.co.ug/new_vision/n...
# 10558           1.0                                                NaN
# 10559           1.0  Official Decree: http://search.ligazakon.ua/l_...
# 10560           1.0                                                NaN
#
#        S2_Workplace closing  S2_IsGeneral  \
# 0                       NaN           NaN
# 1                       0.0           NaN
# 2                       NaN           NaN
# 3                       0.0           NaN
# 4                       NaN           NaN
# ...                     ...           ...
# 10556                   2.0           1.0
# 10557                   2.0           1.0
# 10558                   NaN           NaN
# 10559                   2.0           1.0
# 10560                   2.0           1.0
#
#                                                 S2_Notes  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 10556  'On March 25, Russian President Vladimir Putin...
# 10557  Link: https://www.aa.com.tr/en/africa/rwanda-i...
# 10558                                                NaN
# 10559  Prohibition on catering establishments (restau...
# 10560                                                NaN
#
#        S3_Cancel public events  ...  S9_Monetary measures  \
# 0                          0.0  ...                   NaN
# 1                          0.0  ...                   0.0
# 2                          NaN  ...                   NaN
# 3                          0.0  ...                  55.0
# 4                          NaN  ...                   NaN
# ...                        ...  ...                   ...
# 10556                      NaN  ...                   NaN
# 10557                      1.0  ...                   NaN
# 10558                      NaN  ...                   NaN
# 10559                      2.0  ...                   NaN
# 10560                      2.0  ...                   NaN
#
#                                                 S9_Notes  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      http://www.bcra.gov.ar/Institucional/Tasa_de_p...
# 4                                                    NaN
# ...                                                  ...
# 10556                                                NaN
# 10557                                                NaN
# 10558                                                NaN
# 10559                                                NaN
# 10560                                                NaN
#
#        S10_Emergency investment in health care  \
# 0                                          0.0
# 1                                          0.0
# 2                                          NaN
# 3                                          0.0
# 4                                          NaN
# ...                                        ...
# 10556                                      NaN
# 10557                                      NaN
# 10558                                      NaN
# 10559                                3508771.0
# 10560                                      NaN
#
#                                                S10_Notes  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 10556                                                NaN
# 10557                                                NaN
# 10558                                                NaN
# 10559  https://www.kmu.gov.ua/news/uryad-prijnyav-niz...
# 10560                                                NaN
#
#       S11_Investment in Vaccines  S11_Notes  ConfirmedCases ConfirmedDeaths  \
# 0                            0.0        NaN             0.0             0.0
# 1                            0.0        NaN             NaN             NaN
# 2                            NaN        NaN             0.0             0.0
# 3                            0.0        NaN             NaN             NaN
# 4                            NaN        NaN             0.0             0.0
# ...                          ...        ...             ...             ...
# 10556                        NaN        NaN             NaN             NaN
# 10557                        NaN        NaN             NaN             NaN
# 10558                        NaN        NaN             NaN             NaN
# 10559                        NaN        NaN             NaN             NaN
# 10560                        NaN        NaN             NaN             NaN
#
#        StringencyIndex  Unnamed: 34
# 0                  0.0           \t
# 1                  0.0           \t
# 2                  NaN           \t
# 3                  0.0           \t
# 4                  NaN           \t
# ...                ...          ...
# 10556              NaN           \t
# 10557             81.0           \t
# 10558              NaN           \t
# 10559             95.0           \t
# 10560             83.0           \t
#
# [10561 rows x 35 columns]

# %% [markdown]
# ### Data Schema
#
# <img src="Oxford_dataset_explanation.png" height=1000, width=500>

# %%
# Preprocessing

# Align date format to match the time-series data below
oxford_data["Date"] = pd.to_datetime(oxford_data["Date"], format="%Y%m%d").dt.strftime("%-m/%-d/%y")

# Align Country Name format
oxford_data["CountryName"][oxford_data["CountryName"].str.contains("Korea")] = "Korea, South"

# %%
oxford_data[oxford_data["CountryName"] == "China"]
# Out:
#       CountryName CountryCode     Date  S1_School closing  S1_IsGeneral  \
# 21          China         CHN   1/1/20                0.0           0.0
# 125         China         CHN   1/2/20                0.0           0.0
# 229         China         CHN   1/3/20                0.0           0.0
# 333         China         CHN   1/4/20                0.0           0.0
# 437         China         CHN   1/5/20                0.0           0.0
# ...           ...         ...      ...                ...           ...
# 9631        China         CHN  3/26/20                2.0           1.0
# 9817        China         CHN  3/27/20                2.0           1.0
# 10004       China         CHN  3/28/20                2.0           1.0
# 10192       China         CHN  3/29/20                2.0           1.0
# 10378       China         CHN  3/30/20                2.0           1.0
#
#                                                 S1_Notes  \
# 21                                                   NaN
# 125                                                  NaN
# 229                                                  NaN
# 333                                                  NaN
# 437                                                  NaN
# ...                                                  ...
# 9631   Schools set to open 7th April. https://www.glo...
# 9817   Schools set to open 7th April. https://www.glo...
# 10004  Schools set to open 7th April. https://www.glo...
# 10192  Schools set to open 7th April. https://www.glo...
# 10378  Schools set to open 7th April. https://www.glo...
#
#        S2_Workplace closing  S2_IsGeneral  \
# 21                      0.0           0.0
# 125                     0.0           0.0
# 229                     0.0           0.0
# 333                     0.0           0.0
# 437                     0.0           0.0
# ...                     ...           ...
# 9631                    1.0           1.0
# 9817                    1.0           1.0
# 10004                   1.0           1.0
# 10192                   1.0           1.0
# 10378                   1.0           1.0
#
#                                                 S2_Notes  \
# 21                                                   NaN
# 125                                                  NaN
# 229                                                  NaN
# 333                                                  NaN
# 437                                                  NaN
# ...                                                  ...
# 9631   Some provinces in china had restrictions eased...
# 9817   Some provinces in china had restrictions eased...
# 10004  Some provinces in china had restrictions eased...
# 10192  Some provinces in china had restrictions eased...
# 10378  Some provinces in china had restrictions eased...
#
#        S3_Cancel public events  ...  S9_Monetary measures  \
# 21                         0.0  ...                  4.15
# 125                        0.0  ...                  4.15
# 229                        0.0  ...                  4.15
# 333                        0.0  ...                  4.15
# 437                        0.0  ...                  4.15
# ...                        ...  ...                   ...
# 9631                       2.0  ...                  4.05
# 9817                       2.0  ...                  4.05
# 10004                      2.0  ...                  4.05
# 10192                      2.0  ...                  4.05
# 10378                      2.0  ...                  4.05
#
#                                                 S9_Notes  \
# 21                                                   NaN
# 125                                                  NaN
# 229                                                  NaN
# 333                                                  NaN
# 437                                                  NaN
# ...                                                  ...
# 9631                                                 NaN
# 9817                                                 NaN
# 10004                                                NaN
# 10192                                                NaN
# 10378  http://www.xinhuanet.com/fortune/2020-03/21/c_...
#
#        S10_Emergency investment in health care  S10_Notes  \
# 21                                         0.0        NaN
# 125                                        0.0        NaN
# 229                                        0.0        NaN
# 333                                        0.0        NaN
# 437                                        0.0        NaN
# ...                                        ...        ...
# 9631                                       NaN        NaN
# 9817                                       NaN        NaN
# 10004                                      NaN        NaN
# 10192                                      NaN        NaN
# 10378                                      NaN        NaN
#
#       S11_Investment in Vaccines  S11_Notes  ConfirmedCases ConfirmedDeaths  \
# 21                           NaN        NaN            27.0             0.0
# 125                          NaN        NaN            27.0             0.0
# 229                          NaN        NaN            44.0             0.0
# 333                          NaN        NaN            44.0             0.0
# 437                          NaN        NaN            59.0             0.0
# ...                          ...        ...             ...             ...
# 9631                         NaN        NaN         81968.0          3293.0
# 9817                         NaN        NaN         82079.0          3298.0
# 10004                        NaN        NaN         82213.0          3301.0
# 10192                        NaN        NaN         82342.0          3306.0
# 10378                        NaN        NaN         82463.0          3311.0
#
#        StringencyIndex  Unnamed: 34
# 21                 0.0           \t
# 125                0.0           \t
# 229                0.0           \t
# 333                0.0           \t
# 437                0.0           \t
# ...                ...          ...
# 9631              76.0           \t
# 9817              76.0           \t
# 10004             67.0           \t
# 10192             67.0           \t
# 10378             67.0           \t
#
# [90 rows x 35 columns]

# %%
# Countries with a high stringency Index
# oxford_data[["CountryName", "StringencyIndex"]].groupby("CountryName").agg(max).sort_values(by="StringencyIndex", axis=0)
oxford_data[["CountryName", "StringencyIndex"]].groupby("CountryName").agg(max).fillna(0).nlargest(30, "StringencyIndex")
# Out:
#                   StringencyIndex
# CountryName
# Croatia                     100.0
# India                       100.0
# Israel                      100.0
# Jordan                      100.0
# Qatar                       100.0
# Zimbabwe                    100.0
# Argentina                    95.0
# Austria                      95.0
# Colombia                     95.0
# Kenya                        95.0
# Panama                       95.0
# Papua New Guinea             95.0
# Serbia                       95.0
# Syria                        95.0
# Ukraine                      95.0
# Bolivia                      93.0
# Pakistan                     93.0
# Hungary                      90.0
# Italy                        90.0
# Spain                        90.0
# Sri Lanka                    90.0
# Switzerland                  90.0
# Turkey                       90.0
# Belgium                      86.0
# France                       86.0
# Malaysia                     86.0
# Netherlands                  86.0
# Romania                      86.0
# South Africa                 86.0
# Uganda                       86.0

# %% [markdown]
# ## Novel Coronavirus (COVID-19) Cases, provided by JHU CSSE
# https://github.com/CSSEGISandData/COVID-19

# %%
cases_dirname = "csse_covid_19_data/csse_covid_19_time_series"
cases = pd.read_csv(os.path.join(cases_dirname, "time_series_covid19_confirmed_global.csv"))
deaths = pd.read_csv(os.path.join(cases_d irname, "time_series_covid19_deaths_global.csv"))

# %%
cases
# Out:
#                Province/State  Country/Region        Lat       Long  1/22/20  \
# 0                         NaN     Afghanistan  33.000000  65.000000        0
# 1                         NaN         Albania  41.153300  20.168300        0
# 2                         NaN         Algeria  28.033900   1.659600        0
# 3                         NaN         Andorra  42.506300   1.521800        0
# 4                         NaN          Angola -11.202700  17.873900        0
# ..                        ...             ...        ...        ...      ...
# 251  Turks and Caicos Islands  United Kingdom  21.694000 -71.797900        0
# 252                       NaN      MS Zaandam   0.000000   0.000000        0
# 253                       NaN        Botswana -22.328500  24.684900        0
# 254                       NaN         Burundi  -3.373100  29.918900        0
# 255                       NaN    Sierra Leone   8.460555 -11.779889        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  3/22/20  3/23/20  \
# 0          0        0        0        0        0  ...       40       40
# 1          0        0        0        0        0  ...       89      104
# 2          0        0        0        0        0  ...      201      230
# 3          0        0        0        0        0  ...      113      133
# 4          0        0        0        0        0  ...        2        3
# ..       ...      ...      ...      ...      ...  ...      ...      ...
# 251        0        0        0        0        0  ...        0        0
# 252        0        0        0        0        0  ...        0        0
# 253        0        0        0        0        0  ...        0        0
# 254        0        0        0        0        0  ...        0        0
# 255        0        0        0        0        0  ...        0        0
#
#      3/24/20  3/25/20  3/26/20  3/27/20  3/28/20  3/29/20  3/30/20  3/31/20
# 0         74       84       94      110      110      120      170      174
# 1        123      146      174      186      197      212      223      243
# 2        264      302      367      409      454      511      584      716
# 3        164      188      224      267      308      334      370      376
# 4          3        3        4        4        5        7        7        7
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 251        0        0        0        0        4        4        5        5
# 252        0        0        0        0        2        2        2        2
# 253        0        0        0        0        0        0        3        4
# 254        0        0        0        0        0        0        0        2
# 255        0        0        0        0        0        0        0        1
#
# [256 rows x 74 columns]

# %%
# aggregate by country and drop unnecessary columns
cases_agg = cases.drop(columns=["Province/State", "Lat", "Long"]).groupby("Country/Region").agg(sum)

# %%
# filter countries with <= 100 cases (as of yesterday)

current_date = (datetime.now() - timedelta(days=1)).strftime("%-m/%-d/%y")
cases_gt_100 = cases_agg[cases_agg[current_date] > 100]
# cases_gt_100.set_index("Country/Region", inplace=True)

# %%
# Transpose
cases_gt_100_T = cases_gt_100.T

# %%
# get top 30 list (based on most recent date)
cases_top_n = cases_gt_100.nlargest(30, current_date).index.values
cases_gt_100.nlargest(30, current_date)
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# US                    1        1        2        2        5        5        5
# Italy                 0        0        0        0        0        0        0
# Spain                 0        0        0        0        0        0        0
# China               548      643      920     1406     2075     2877     5509
# Germany               0        0        0        0        0        1        4
# France                0        0        2        3        3        3        4
# Iran                  0        0        0        0        0        0        0
# United Kingdom        0        0        0        0        0        0        0
# Switzerland           0        0        0        0        0        0        0
# Turkey                0        0        0        0        0        0        0
# Belgium               0        0        0        0        0        0        0
# Netherlands           0        0        0        0        0        0        0
# Austria               0        0        0        0        0        0        0
# Korea, South          1        1        2        2        3        4        4
# Canada                0        0        0        0        1        1        2
# Portugal              0        0        0        0        0        0        0
# Brazil                0        0        0        0        0        0        0
# Israel                0        0        0        0        0        0        0
# Norway                0        0        0        0        0        0        0
# Australia             0        0        0        0        4        5        5
# Sweden                0        0        0        0        0        0        0
# Czechia               0        0        0        0        0        0        0
# Ireland               0        0        0        0        0        0        0
# Denmark               0        0        0        0        0        0        0
# Malaysia              0        0        0        3        4        4        4
# Chile                 0        0        0        0        0        0        0
# Russia                0        0        0        0        0        0        0
# Poland                0        0        0        0        0        0        0
# Romania               0        0        0        0        0        0        0
# Ecuador               0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  3/22/20  3/23/20  3/24/20  \
# Country/Region                             ...
# US                    5        5        7  ...    33276    43847    53740
# Italy                 0        0        2  ...    59138    63927    69176
# Spain                 0        0        0  ...    28768    35136    39885
# China              6087     8141     9802  ...    81435    81498    81591
# Germany               4        4        5  ...    24873    29056    32986
# France                5        5        5  ...    16243    20123    22622
# Iran                  0        0        0  ...    21638    23049    24811
# United Kingdom        0        0        2  ...     5745     6726     8164
# Switzerland           0        0        0  ...     7474     8795     9877
# Turkey                0        0        0  ...     1236     1529     1872
# Belgium               0        0        0  ...     3401     3743     4269
# Netherlands           0        0        0  ...     4217     4764     5580
# Austria               0        0        0  ...     3582     4474     5283
# Korea, South          4        4       11  ...     8961     8961     9037
# Canada                2        2        4  ...     1469     2088     2790
# Portugal              0        0        0  ...     1600     2060     2362
# Brazil                0        0        0  ...     1546     1924     2247
# Israel                0        0        0  ...      883     1071     1238
# Norway                0        0        0  ...     2385     2621     2863
# Australia             6        9        9  ...     1549     1682     2044
# Sweden                0        0        1  ...     1934     2046     2286
# Czechia               0        0        0  ...     1120     1236     1394
# Ireland               0        0        0  ...      906     1125     1329
# Denmark               0        0        0  ...     1514     1572     1718
# Malaysia              7        8        8  ...     1306     1518     1624
# Chile                 0        0        0  ...      632      746      922
# Russia                0        0        2  ...      367      438      495
# Poland                0        0        0  ...      634      749      901
# Romania               0        0        0  ...      433      576      794
# Ecuador               0        0        0  ...      789      981     1082
#
#                 3/25/20  3/26/20  3/27/20  3/28/20  3/29/20  3/30/20  3/31/20
# Country/Region
# US                65778    83836   101657   121478   140886   161807   188172
# Italy             74386    80589    86498    92472    97689   101739   105792
# Spain             49515    57786    65719    73235    80110    87956    95923
# China             81661    81782    81897    81999    82122    82198    82279
# Germany           37323    43938    50871    57695    62095    66885    71808
# France            25600    29551    33402    38105    40708    45170    52827
# Iran              27017    29406    32332    35408    38309    41495    44605
# United Kingdom     9640    11812    14745    17312    19780    22453    25481
# Switzerland       10897    11811    12928    14076    14829    15922    16605
# Turkey             2433     3629     5698     7402     9217    10827    13531
# Belgium            4937     6235     7284     9134    10836    11899    12775
# Netherlands        6438     7468     8647     9819    10930    11817    12667
# Austria            5588     6909     7657     8271     8788     9618    10180
# Korea, South       9137     9241     9332     9478     9583     9661     9786
# Canada             3251     4042     4682     5576     6280     7398     8527
# Portugal           2995     3544     4268     5170     5962     6408     7443
# Brazil             2554     2985     3417     3904     4256     4579     5717
# Israel             2369     2693     3035     3619     4247     4695     5358
# Norway             3084     3369     3755     4015     4284     4445     4641
# Australia          2364     2810     3143     3640     3984     4361     4559
# Sweden             2526     2840     3069     3447     3700     4028     4435
# Czechia            1654     1925     2279     2631     2817     3001     3308
# Ireland            1564     1819     2121     2415     2615     2910     3235
# Denmark            1862     2023     2200     2366     2564     2755     3039
# Malaysia           1796     2031     2161     2320     2470     2626     2766
# Chile              1142     1306     1610     1909     2139     2449     2738
# Russia              658      840     1036     1264     1534     1836     2337
# Poland             1051     1221     1389     1638     1862     2055     2311
# Romania             906     1029     1292     1452     1815     2109     2245
# Ecuador            1173     1403     1595     1823     1924     1962     2240
#
# [30 rows x 70 columns]

# %%
# Plot All countries 

# num_countries = 100
# cases_gt_100_cols = np.random.choice(cases_gt_100_T.columns.values, num_countries, replace=False)

cases_gt_100_T_index = cases_gt_100_T.index.values
plt.plot(cases_gt_100_T[cases_top_n])
plt.legend(cases_top_n, loc='center right')

# %% [markdown]
# ### China and South Korea (at current date: 4/1/2020) has tailed off and thus follows a logistic curve

# %%
# Plot China and Korea
cases_gt_100_T_index = cases_gt_100_T.index.values
plt.plot(cases_gt_100_T[["China", "Korea, South"]])
plt.legend(["China", "Korea, South"], loc='best')

# %% [markdown]
# ## Humanitarian aid to country based on Socio-Economic factors.
# https://www.kaggle.com/hellbuoy/pca-kmeans-hierarchical-clustering

# %%
economic_data = pd.read_csv(os.path.join(data_dirname, "Country-data.csv"))
economic_data
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp
# 0         9.44        56.2       5.82    553
# 1         4.49        76.3       1.65   4090
# 2        16.10        76.5       2.89   4460
# 3        22.40        60.1       6.16   3530
# 4         1.44        76.8       2.13  12200
# ..         ...         ...        ...    ...
# 162       2.62        63.0       3.50   2970
# 163      45.90        75.4       2.47  13500
# 164      12.10        73.1       1.95   1310
# 165      23.60        67.5       4.67   1310
# 166      14.00        52.0       5.40   1460
#
# [167 rows x 10 columns]

# %% [markdown]
# ## Population by Country - 2020
# https://www.kaggle.com/tanuprabhu/population-by-country-2020

# %%
population_data = pd.read_csv(os.path.join(data_dirname, "population_by_country_2020.csv"))
population_data
# Out:
#     Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                     China         1439323776         0.39%     5540090
# 1                     India         1380004385         0.99%    13586631
# 2             United States          331002651         0.59%     1937734
# 3                 Indonesia          273523615         1.07%     2898047
# 4                  Pakistan          220892340         2.00%     4327022
# ..                      ...                ...           ...         ...
# 230              Montserrat               4992         0.06%           3
# 231        Falkland Islands               3480         3.05%         103
# 232                    Niue               1626         0.68%          11
# 233                 Tokelau               1357         1.27%          17
# 234                Holy See                801         0.25%           2
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0                153          9388211       -348399.0        1.7       38
# 1                464          2973190       -532687.0        2.2       28
# 2                 36          9147420        954806.0        1.8       38
# 3                151          1811570        -98955.0        2.3       30
# 4                287           770880       -233379.0        3.6       23
# ..               ...              ...             ...        ...      ...
# 230               50              100             NaN       N.A.     N.A.
# 231                0            12170             NaN       N.A.     N.A.
# 232                6              260             NaN       N.A.     N.A.
# 233              136               10             NaN       N.A.     N.A.
# 234             2003                0             NaN       N.A.     N.A.
#
#     Urban Pop % World Share
# 0           61%      18.47%
# 1           35%      17.70%
# 2           83%       4.25%
# 3           56%       3.51%
# 4           35%       2.83%
# ..          ...         ...
# 230         10%       0.00%
# 231         66%       0.00%
# 232         46%       0.00%
# 233          0%       0.00%
# 234        N.A.       0.00%
#
# [235 rows x 11 columns]
